# %%
train_df.describe()
# Out:
#          bathrooms      bedrooms      latitude    listing_id     longitude  \
# count  49352.00000  49352.000000  49352.000000  4.935200e+04  49352.000000
# mean       1.21218      1.541640     40.741545  7.024055e+06    -73.955716
# std        0.50142      1.115018      0.638535  1.262746e+05      1.177912
# min        0.00000      0.000000      0.000000  6.811957e+06   -118.271000
# 25%        1.00000      1.000000     40.728300  6.915888e+06    -73.991700
# 50%        1.00000      1.000000     40.751800  7.021070e+06    -73.977900
# 75%        1.00000      2.000000     40.774300  7.128733e+06    -73.954800
# max       10.00000      8.000000     44.883500  7.753784e+06      0.000000
#
#               price
# count  4.935200e+04
# mean   3.830174e+03
# std    2.206687e+04
# min    4.300000e+01
# 25%    2.500000e+03
# 50%    3.150000e+03
# 75%    4.100000e+03
# max    4.490000e+06

# %%
# how many features does the apt have?
train_df['num_features'] = train_df.features.map(lambda x: len(x))

# %%
# the interest level decreases as the average number of bathrooms decreases
fig, axes =plt.subplots(ncols=2, nrows=1, figsize = (10,6))
sns.barplot(x =  train_df.interest_level, y = train_df.bathrooms, order = ['low','medium','high'], ax=axes[0])
sns.barplot(x =  train_df.interest_level, y = train_df.bedrooms, order = ['low','medium','high'], ax=axes[1])

# %%
# the interest level increases as the average price decreases
fig, axes =plt.subplots(ncols=2, nrows=1, figsize = (12,8))
sns.pointplot(x =  train_df.interest_level, y = train_df.price, order = ['low','medium','high'], ax=axes[0])
sns.countplot(train_df.num_features, ax=axes[1])

# %%
help(sns.pointplot)
# Out:
# Help on function pointplot in module seaborn.categorical:
#
# pointplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean>, ci=95, n_boot=1000, units=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, ax=None, **kwargs)
#     Show point estimates and confidence intervals using scatter plot glyphs.
#
#     A point plot represents an estimate of central tendency for a numeric
#     variable by the position of scatter plot points and provides some
#     indication of the uncertainty around that estimate using error bars.
#
#     Point plots can be more useful than bar plots for focusing comparisons
#     between different levels of one or more categorical variables. They are
#     particularly adept at showing interactions: how the relationship between
#     levels of one categorical variable changes across levels of a second
# ...
